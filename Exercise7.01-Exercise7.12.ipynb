# %% [markdown]
# # CH. 7 - TOPIC MODELS
# ## Exercises

# %% [markdown]
# #### Exercise 7.01: Load Libraries

# %%
# not necessary

# put this in to block deprecation warnings
# from pyLDAvis

import warnings
warnings.filterwarnings('ignore')

# %%
import langdetect  # language detection
import matplotlib.pyplot  # plotting
import nltk  # natural language processing
import numpy  # arrays and matrices
import pandas  # dataframes
import pyLDAvis  # plotting
import pyLDAvis.sklearn  # plotting
import regex  # regular expressions
import sklearn  # machine learning

# %%
# installing specific word dictionarys
# used for stopword removal and lemmatization

nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading wordnet: <urlopen error unknown url type:
# [nltk_data]     https>
# [nltk_data] Error loading stopwords: <urlopen error unknown url type:
# [nltk_data]     https>
# False

# %%
# %matplotlib inline

# %% [markdown]
# #### Exercise 7.02: Load and Examine Data

# %%
# define path and load data

path = "News_Final.csv"
df = pandas.read_csv(path, header=0)

# %%
# define quick look function for data frame

def dataframe_quick_look(df, nrows):
    print("SHAPE:\n{shape}\n".format(shape=df.shape))
    print("COLUMN NAMES:\n{names}\n".format(names=df.columns))
    print("HEAD:\n{head}\n".format(head=df.head(nrows)))

# %%
dataframe_quick_look(df, nrows=2)
# Out:
# SHAPE:
# (93239, 11)
#
# COLUMN NAMES:
# Index(['IDLink', 'Title', 'Headline', 'Source', 'Topic', 'PublishDate',
#        'SentimentTitle', 'SentimentHeadline', 'Facebook', 'GooglePlus',
#        'LinkedIn'],
#       dtype='object')
#
# HEAD:
#     IDLink                                             Title  \
# 0  99248.0  Obama Lays Wreath at Arlington National Cemetery
# 1  10423.0       A Look at the Health of the Chinese Economy
#
#                                             Headline     Source    Topic  \
# 0  Obama Lays Wreath at Arlington National Cemete...  USA TODAY    obama
# 1  Tim Haywood, investment director business-unit...  Bloomberg  economy
#
#            PublishDate  SentimentTitle  SentimentHeadline  Facebook  \
# 0  2002-04-02 00:00:00        0.000000          -0.053300        -1
# 1  2008-09-20 00:00:00        0.208333          -0.156386        -1
#
#    GooglePlus  LinkedIn
# 0          -1        -1
# 1          -1        -1

# %%
# data set came with prespecified topics
# print the topics out with counts

print("TOPICS:\n{topics}\n".format(topics=df["Topic"].value_counts()))
# Out:
# TOPICS:
# economy      33928
# obama        28610
# microsoft    21858
# palestine     8843
# Name: Topic, dtype: int64

# %%
# lets look at the final data we are going to move forward with

raw = df["Headline"].tolist()
print("HEADLINES:\n{lines}\n".format(lines=raw[:5]))
print("LENGTH:\n{length}\n".format(length=len(raw)))
# Out:
# HEADLINES:
# ['Obama Lays Wreath at Arlington National Cemetery. President Barack Obama has laid a wreath at the Tomb of the Unknowns to honor', 'Tim Haywood, investment director business-unit head for fixed income at Gam, discusses the China beige book and the state of the economy.', "Nouriel Roubini, NYU professor and chairman at Roubini Global Economics, explains why the global economy isn't facing the same conditions", "Finland's economy expanded marginally in the three months ended December, after contracting in the previous quarter, preliminary figures from Statistics Finland showed Monday. ", 'Tourism and public spending continued to boost the economy in January, in light of contraction in private consumption and exports, according to the Bank of Thailand data. ']
#
# LENGTH:
# 93239

# %% [markdown]
# #### Exercise 7.03: Step-by-step Data Cleaning

# %%
# select one headline to use as an example

example = raw[5]
print(example)
# Out:
# Over 100 attendees expected to see latest version of Microsoft Dynamics SL and Dynamics GP (PRWeb February 29, 2016) Read the full story at http://www.prweb.com/releases/2016/03/prweb13238571.htm

# %%
# check language of headline
# filter to english only

def do_language_identifying(txt):
    try: the_language = langdetect.detect(txt)
    except: the_language = 'none'
    return the_language

# %%
print("DETECTED LANGUAGE:\n{lang}\n".format(lang=do_language_identifying(example)))
# Out:
# DETECTED LANGUAGE:
# en

# %%
# tokenize the data

example = example.split(" ")
print(example)
# Out:
# ['Over', '100', 'attendees', 'expected', 'to', 'see', 'latest', 'version', 'of', 'Microsoft', 'Dynamics', 'SL', 'and', 'Dynamics', 'GP', '(PRWeb', 'February', '29,', '2016)', 'Read', 'the', 'full', 'story', 'at', 'http://www.prweb.com/releases/2016/03/prweb13238571.htm', '']

# %%
# find and replace website addresses

example = [
    'URL' if bool(regex.search("http[s]?://", i)) 
    else i for i in example
]
print(example)
# Out:
# ['Over', '100', 'attendees', 'expected', 'to', 'see', 'latest', 'version', 'of', 'Microsoft', 'Dynamics', 'SL', 'and', 'Dynamics', 'GP', '(PRWeb', 'February', '29,', '2016)', 'Read', 'the', 'full', 'story', 'at', 'URL', '']

# %%
# remove punctuation

example = [regex.sub("[^\\w\\s]|\n", "", i) for i in example]
print(example)
# Out:
# ['Over', '100', 'attendees', 'expected', 'to', 'see', 'latest', 'version', 'of', 'Microsoft', 'Dynamics', 'SL', 'and', 'Dynamics', 'GP', 'PRWeb', 'February', '29', '2016', 'Read', 'the', 'full', 'story', 'at', 'URL', '']

# %%
# remove numbers

example = [regex.sub("^[0-9]*$", "", i) for i in example]
print(example)
# Out:
# ['Over', '', 'attendees', 'expected', 'to', 'see', 'latest', 'version', 'of', 'Microsoft', 'Dynamics', 'SL', 'and', 'Dynamics', 'GP', 'PRWeb', 'February', '', '', 'Read', 'the', 'full', 'story', 'at', 'URL', '']

# %%
# make everything lowercase

example = [i.lower() if i not in ["URL"] else i for i in example]
print(example)
# Out:
# ['over', '', 'attendees', 'expected', 'to', 'see', 'latest', 'version', 'of', 'microsoft', 'dynamics', 'sl', 'and', 'dynamics', 'gp', 'prweb', 'february', '', '', 'read', 'the', 'full', 'story', 'at', 'URL', '']

# %%
# remove the url placeholder

example = [i for i in example if i not in ["URL",""]]
print(example)
# Out:
# ['over', 'attendees', 'expected', 'to', 'see', 'latest', 'version', 'of', 'microsoft', 'dynamics', 'sl', 'and', 'dynamics', 'gp', 'prweb', 'february', 'read', 'the', 'full', 'story', 'at']

# %%
# remove stopwords
# uses stopwords dictionary previously loaded

list_stop_words = nltk.corpus.stopwords.words("English")
list_stop_words = [regex.sub("[^\\w\\s]", "", i) for i in list_stop_words]
print(list_stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', 'arent', 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', 'couldnt', 'd', 'did', 'didn', 'didnt', 'do', 'does', 'doesn', 'doesnt', 'doing', 'don', 'dont', 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', 'hadnt', 'has', 'hasn', 'hasnt', 'have', 'haven', 'havent', 'having', 'he', 'hed', 'hell', 'her', 'here', 'hers', 'herself', 'hes', 'him', 'himself', 'his', 'how', 'i', 'id', 'if', 'ill', 'im', 'in', 'into', 'is', 'isn', 'isnt', 'it', 'itd', 'itll', 'its', 'its', 'itself', 'ive', 'just', 'll', 'm', 'ma', 'me', 'mightn', 'mightnt', 'more', 'most', 'mustn', 'mustnt', 'my', 'myself', 'needn', 'neednt', 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', 'shant', 'she', 'shed', 'shell', 'shes', 'should', 'shouldn', 'shouldnt', 'shouldve', 'so', 'some', 'such', 't', 'than', 'that', 'thatll', 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'theyd', 'theyll', 'theyre', 'theyve', 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', 'wasnt', 'we', 'wed', 'well', 'were', 'were', 'weren', 'werent', 'weve', 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', 'wont', 'wouldn', 'wouldnt', 'y', 'you', 'youd', 'youll', 'your', 'youre', 'yours', 'yourself', 'yourselves', 'youve']

# %%
example = [i for i in example if i not in list_stop_words]
print(example)
# Out:
# ['attendees', 'expected', 'see', 'latest', 'version', 'microsoft', 'dynamics', 'sl', 'dynamics', 'gp', 'prweb', 'february', 'read', 'full', 'story']

# %%
# perform lemmatization
# uses wordnet dictionary previously loaded

def do_lemmatizing(wrd):
    out = nltk.corpus.wordnet.morphy(wrd)
    return (wrd if out is None else out)

# %%
example = [do_lemmatizing(i) for i in example]
print(example)
# Out:
# ['attendee', 'expect', 'see', 'latest', 'version', 'microsoft', 'dynamics', 'sl', 'dynamics', 'gp', 'prweb', 'february', 'read', 'full', 'story']

# %%
# remove words less than 5 characters long

example = [i for i in example if len(i) >= 5]
print(example)
# Out:
# ['attendee', 'expect', 'latest', 'version', 'microsoft', 'dynamics', 'dynamics', 'prweb', 'february', 'story']

# %% [markdown]
# #### Exercise 7.04: Complete Data Cleaning

# %%
# define consolidated data cleaning function

def do_headline_cleaning(txt):
    # identify language of tweet
    # return null if language not english
    lg = do_language_identifying(txt)
    if lg != 'en':
        return None
    
    # split the string on whitespace
    out = txt.split(" ")
    
    # identify urls
    # replace with URL
    out = ['URL' if bool(regex.search("http[s]?://", i)) else i for i in out]
    
    # remove all punctuation
    out = [regex.sub("[^\\w\\s]|\n", "", i) for i in out]
    
    # remove all numerics
    out = [regex.sub("^[0-9]*$", "", i) for i in out]
    
    # make all non-keywords lowercase
    out = [i.lower() if i not in ["URL"] else i for i in out]
    
    # remove URL
    out = [i for i in out if i not in ["URL",""]]
    
    # remove stopwords
    list_stop_words = nltk.corpus.stopwords.words("english")
    list_stop_words = [regex.sub("[^\\w\\s]", "", i) for i in list_stop_words]
    
    out = [i for i in out if i not in list_stop_words]
    
    # lemmatizing
    out = [do_lemmatizing(i) for i in out]
    
    # keep words 5 or more characters long
    out = [i for i in out if len(i) >= 5]
    
    return out

from time import time

# %%
# execute function
# takes several minutes
tick = time()
clean = list(map(do_headline_cleaning, raw))
print(time()-tick)
# Out:
# 534.3242785930634

# %%
# remove none types

clean = list(filter(None.__ne__, clean))
print("HEADLINES:\n{lines}\n".format(lines=clean[:5]))
print("LENGTH:\n{length}\n".format(length=len(clean)))
# Out:
# HEADLINES:
# [['obama', 'wreath', 'arlington', 'national', 'cemetery', 'president', 'barack', 'obama', 'wreath', 'unknown', 'honor'], ['haywood', 'investment', 'director', 'businessunit', 'income', 'discus', 'china', 'beige', 'state', 'economy'], ['nouriel', 'roubini', 'professor', 'chairman', 'roubini', 'global', 'economics', 'explain', 'global', 'economy', 'facing', 'conditions'], ['finland', 'economy', 'expand', 'marginally', 'three', 'month', 'december', 'contracting', 'previous', 'quarter', 'preliminary', 'figure', 'statistics', 'finland', 'monday'], ['tourism', 'public', 'spending', 'continue', 'boost', 'economy', 'january', 'light', 'contraction', 'private', 'consumption', 'export', 'accord', 'thailand']]
#
# LENGTH:
# 92950

# %%
# turn tokens back into string
# concatenate with white spaces

clean_sentences = [" ".join(i) for i in clean]

# %%
print(clean_sentences[0:10])
# Out:
# ['obama wreath arlington national cemetery president barack obama wreath unknown honor', 'haywood investment director businessunit income discus china beige state economy', 'nouriel roubini professor chairman roubini global economics explain global economy facing conditions', 'finland economy expand marginally three month december contracting previous quarter preliminary figure statistics finland monday', 'tourism public spending continue boost economy january light contraction private consumption export accord thailand', 'attendee expect latest version microsoft dynamics dynamics prweb february story', 'ramallah february palestine liberation organization sectretarygeneral erekat thursday express concern kenyan president uhuru kenyattas visit jerusalem jordan valley', 'first michelle obama speak state white house washington wednesday interactive student workshop musical legacy charles student school community organization across country participate quotin performance white housequot series', 'hancock county early monday morning family years', 'delhi feb29 technology giant microsoft target rival apple series focusing windows gross windows machine']

# %% [markdown]
# #### Exercise 7.05: Count Vectorizer

# %%
# define some global variables

number_words = 10
number_docs = 10
number_features = 1000

# %%
# execute bag of words model
# use raw term counts for lda 
# as it is a probabilistic graphical model

vectorizer1 = sklearn.feature_extraction.text.CountVectorizer(
    analyzer="word",
    max_df=0.5, 
    min_df=20, 
    max_features=number_features
)
clean_vec1 = vectorizer1.fit_transform(clean_sentences)
print(clean_vec1[0])

feature_names_vec1 = vectorizer1.get_feature_names()
# Out:
#   (0, 573)	2
#   (0, 558)	1
#   (0, 645)	1
#   (0, 88)	1
#   (0, 408)	1

# %% [markdown]
# #### Exercise 7.06: Select Number of Topics

# %%
# define function to calculate perplexity for LDA model trained on ntopics

def perplexity_by_ntopic(data, ntopics):
    output_dict = {
        "Number Of Topics": [], 
        "Perplexity Score": []
    }
    
    for t in ntopics:
        lda = sklearn.decomposition.LatentDirichletAllocation(
            n_components=t,
            learning_method="online",
            random_state=0
        )
        lda.fit(data)
        
        output_dict["Number Of Topics"].append(t)
        output_dict["Perplexity Score"].append(lda.perplexity(data))
        
    output_df = pandas.DataFrame(output_dict)
    
    index_min_perplexity = output_df["Perplexity Score"].idxmin()
    output_num_topics = output_df.loc[
        index_min_perplexity,  # index
        "Number Of Topics"  # column
    ]
        
    return (output_df, output_num_topics)

# %%
# find perplexity scores for several different numbers of topics
# takes several minutes

df_perplexity, optimal_num_topics = perplexity_by_ntopic(
    clean_vec1, 
    ntopics=[1, 2, 3, 4, 6, 8, 10]
)

# %%
print(df_perplexity)
# Out:
#    Number Of Topics  Perplexity Score
# 0                 1        509.986884
# 1                 2        443.903474
# 2                 3        408.894492
# 3                 4        433.472369
# 4                 6        503.179390
# 5                 8        544.927029
# 6                10        583.866649

# %%
df_perplexity.plot.line("Number Of Topics", "Perplexity Score")

# %% [markdown]
# #### Exercise 7.07: Latent Dirichlet Allocation

# %%
# define and fit LDA model

lda = sklearn.decomposition.LatentDirichletAllocation(
    n_components=optimal_num_topics,
    learning_method="online",
    random_state=0
)
lda.fit(clean_vec1)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=3, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
# output matrix
# h: docs to topics

lda_transform = lda.transform(clean_vec1)
print(lda_transform.shape)
print(lda_transform)
# Out:
# (92950, 3)
# [[0.04761959 0.9042166  0.04816381]
#  [0.04265014 0.04707049 0.91027937]
#  [0.16847418 0.04278859 0.78873722]
#  ...
#  [0.03998321 0.55888835 0.40112844]
#  [0.06915666 0.86178916 0.06905418]
#  [0.45244811 0.30443739 0.2431145 ]]

# %%
# output matrix
# w: words to topics

lda_components = lda.components_
print(lda_components.shape)
print(lda_components)
# Out:
# (3, 1000)
# [[3.35479167e-01 1.99688784e+02 1.00829412e+01 ... 3.35346622e-01
#   1.99989170e+02 4.03474119e-01]
#  [2.74827277e+02 3.94988439e-01 3.63455723e-01 ... 3.46358973e-01
#   1.79912142e+02 4.60320695e+02]
#  [3.37092041e-01 7.28687034e+01 2.05459985e+02 ... 2.31719306e+02
#   1.23564188e+02 2.09299304e+00]]

# %%
# define function to reformat output matrices into easily readable tables

def get_topics(mod, vec, names, docs, ndocs, nwords):
    # word to topic matrix
    W = mod.components_
    W_norm = W / W.sum(axis=1)[:, numpy.newaxis]
    # topic to document matrix
    H = mod.transform(vec)
    
    W_dict = {}
    H_dict = {}
    
    for tpc_idx, tpc_val in enumerate(W_norm):
        topic = "Topic{}".format(tpc_idx)
        
        # formatting w
        W_indices = tpc_val.argsort()[::-1][:nwords]
        W_names_values = [
            (round(tpc_val[j], 4), names[j]) 
            for j in W_indices
        ]
        W_dict[topic] = W_names_values
        
        # formatting h
        H_indices = H[:, tpc_idx].argsort()[::-1][:ndocs]
        H_names_values = [
            (round(H[:, tpc_idx][j], 4), docs[j]) 
            for j in H_indices
        ]
        H_dict[topic] = H_names_values
        
    W_df = pandas.DataFrame(
        W_dict, 
        index=["Word" + str(i) for i in range(nwords)]
    )
    H_df = pandas.DataFrame(
        H_dict,
        index=["Doc" + str(i) for i in range(ndocs)]
    )
        
    return (W_df, H_df)

# %%
# run function

W_df, H_df = get_topics(
    mod=lda,
    vec=clean_vec1,
    names=feature_names_vec1,
    docs=raw,
    ndocs=number_docs, 
    nwords=number_words
)

# %%
# word-topic table

print(W_df)
# Out:
#                      Topic0                 Topic1                Topic2
# Word0   (0.1058, microsoft)        (0.0877, obama)     (0.0983, economy)
# Word1     (0.0242, windows)     (0.076, president)    (0.0338, economic)
# Word2     (0.0237, company)       (0.0437, barack)      (0.0171, growth)
# Word3  (0.0191, microsofts)    (0.0158, palestine)      (0.0145, global)
# Word4    (0.0162, announce)        (0.0141, state)       (0.0132, world)
# Word5       (0.0145, today)       (0.0137, obamas)       (0.0113, china)
# Word6     (0.0108, release)    (0.013, washington)     (0.0106, percent)
# Word7      (0.0091, update)  (0.0124, palestinian)  (0.0105, government)
# Word8    (0.0089, business)        (0.0113, house)     (0.0097, country)
# Word9     (0.0077, surface)        (0.0104, white)      (0.0095, market)

# %%
# document-topic table

print(H_df)
# Out:
#                                                  Topic0  \
# Doc0  (0.9776, I imagine them bonding over the moral...
# Doc1  (0.9764, &quot;We have put the utmost priority...
# Doc2  (0.9756, President Obama is accusing the media...
# Doc3  (0.9754, A teaching method that focuses on pro...
# Doc4  (0.9754, TSURUGA, Japan """ Visiting Hiroshima...
# Doc5  (0.9754, Software maker Microsoft Corp is sell...
# Doc6  (0.9752, While Apple is embroiled in a fight w...
# Doc7  (0.9751, President Obama struck a somber tone,...
# Doc8  (0.9749, The Estonian economy was also positiv...
# Doc9  (0.9749, 2 economy could be sucked into a Japa...
#
#                                                  Topic1  \
# Doc0  (0.9798, Jews, you will not enjoy in Palestine...
# Doc1  (0.9779, XBOX ONE Backward Compatibility has F...
# Doc2  (0.9779, Microsoft is once again challenging U...
# Doc3  (0.9779, Last quarter, Microsoft hit a major m...
# Doc4  (0.9779, After seeing Kinect fail to connect w...
# Doc5  (0.9779, Microsoft on Thursday posted revenue ...
# Doc6  (0.9774, The unemployment rate for black teens...
# Doc7  (0.9774, Preying on the minds of financial mar...
# Doc8  (0.9773, Because Microsoft collects data conti...
# Doc9  (0.9773, Former finance minister P Chidambaram...
#
#                                                  Topic2
# Doc0  (0.9788, Microsoft buys Talko to make Skype be...
# Doc1  (0.9781, The German government is pencilling i...
# Doc2  (0.9781, Minority businesses could boost the e...
# Doc3  (0.978, ALAMEDA, CA--(Marketwired - Mar 22, 20...
# Doc4  (0.9779, Wall Street opened lower for the thir...
# Doc5  (0.9779, Microsoft said Monday that it is buyi...
# Doc6  (0.9779, Microsoft has been on the acquisition...
# Doc7  (0.9778, Mobile security specialist Lookout ha...
# Doc8  (0.9777, President Barack Obama embraces Hilla...
# Doc9  (0.9773, The past week was one of those where ...

# %% [markdown]
# #### Exercise 7.08: Visualizing LDA

# %%
# iterative visualization
# featuring pca biplot and histogram
lda_plot = pyLDAvis.sklearn.prepare(lda, clean_vec1, vectorizer1, R=10,  n_jobs=1)
pyLDAvis.display(lda_plot)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1451223822337851603326287156"></div>
# <script type="text/javascript">
#
# var ldavis_el1451223822337851603326287156_data = {"mdsDat": {"x": [0.23883962101780049, 0.03034009811182982, -0.2691797191296301], "y": [0.16536250896543628, -0.2804734373285942, 0.11511092836315796], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [38.9644877232129, 34.76076487459107, 26.274747402196024]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3"], "Freq": [21475.0, 26385.0, 26393.0, 22881.0, 13148.0, 9077.0, 4920.0, 4806.0, 3884.0, 4592.0, 26392.622705709564, 22880.539435030172, 13147.728723020293, 4767.738970670423, 4114.284566078629, 3730.221331099616, 3925.6101920240335, 3390.988492976464, 3126.1193156074983, 3052.241473766511, 4245.024074182043, 26384.50254718998, 9076.771229301203, 4592.229968990881, 3903.146412434967, 3031.4448985245267, 2838.1160370391935, 2460.820621715587, 2153.318940172987, 1961.903866975951, 1505.177237038009, 1505.5297904863185, 3540.0169239456495, 2820.1591739100013, 2556.1361745862214, 2605.8110456375207, 21474.74221386095, 4920.306731493925, 4805.940707386528, 3883.9640520413923, 2939.942468111801, 1840.5955404153792, 1562.753679003968, 1514.5434241844946, 1496.5298301101184, 1481.010982724957, 3284.124099878038, 2200.272060465118, 1810.9246815768736], "Term": ["microsoft", "economy", "obama", "president", "barack", "economic", "windows", "company", "microsofts", "growth", "obama", "president", "barack", "palestine", "obamas", "palestinian", "washington", "house", "white", "administration", "state", "economy", "economic", "growth", "global", "china", "percent", "quarter", "expect", "european", "britain", "financial", "world", "government", "market", "country", "microsoft", "windows", "company", "microsofts", "today", "update", "surface", "software", "cloud", "technology", "announce", "release", "business"], "Total": [21475.0, 26385.0, 26393.0, 22881.0, 13148.0, 9077.0, 4920.0, 4806.0, 3884.0, 4592.0, 26393.315301534185, 22881.237108105506, 13148.41729803172, 4768.4485829186815, 4114.97893737825, 3730.918741763203, 3926.3713345754218, 3391.6821108723652, 3126.8135798872013, 3052.9471852350703, 5361.1284056338045, 26385.199183290937, 9077.471784808231, 4592.9138938975775, 3903.876831262633, 3032.1425471530283, 2838.804237158878, 2461.5043045408506, 2154.119064498838, 1962.6337454763036, 1505.900589522952, 1506.2670335648945, 4231.94182378864, 3307.798697199122, 2998.939262362169, 3485.1365412783316, 21475.412420121982, 4920.970936836901, 4806.643056305065, 3884.6325491689477, 2940.7047557819783, 1841.2750284351505, 1563.420465513972, 1515.214200653686, 1497.2041365615692, 1481.698074515684, 3791.9074190871347, 2676.2951583836475, 3280.0836309946135], "loglift": [10.0, 9.0, 8.0, 7.0, 6.0, 5.0, 4.0, 3.0, 2.0, 1.0, 0.9425, 0.9425, 0.9425, 0.9424, 0.9424, 0.9423, 0.9423, 0.9423, 0.9423, 0.9423, 0.7091, 1.0567, 1.0566, 1.0565, 1.0565, 1.0565, 1.0564, 1.0564, 1.0563, 1.0563, 1.0562, 1.0562, 0.8782, 0.8972, 0.8969, 0.7659, 1.3365, 1.3364, 1.3364, 1.3364, 1.3363, 1.3362, 1.3361, 1.3361, 1.3361, 1.3361, 1.1928, 1.1407, 0.7425], "logprob": [10.0, 9.0, 8.0, 7.0, 6.0, 5.0, 4.0, 3.0, 2.0, 1.0, -2.4337, -2.5765, -3.1305, -4.1449, -4.2923, -4.3903, -4.3392, -4.4856, -4.567, -4.5909, -4.261, -2.3198, -3.3869, -4.0682, -4.2308, -4.4836, -4.5495, -4.6921, -4.8256, -4.9187, -5.1837, -5.1835, -4.3285, -4.5558, -4.6541, -4.6349, -2.2458, -3.7193, -3.7429, -3.9559, -4.2343, -4.7026, -4.8663, -4.8976, -4.9096, -4.92, -4.1236, -4.5241, -4.7189]}, "token.table": {"Topic": [1, 1, 3, 1, 2, 2, 3, 2, 3, 3, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 3, 3 ...
#
# function LDAvis_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(LDAvis) !== "undefined"){
#    // already loaded: just create the visualization
#    !function(LDAvis){
#        new LDAvis("#" + "ldavis_el1451223822337851603326287156", ldavis_el1451223822337851603326287156_data);
#    }(LDAvis);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/LDAvis
#    require.config({paths: {d3: "https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       LDAvis_load_lib("https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.js", function(){
#         new LDAvis("#" + "ldavis_el1451223822337851603326287156", ldavis_el1451223822337851603326287156_data);
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & LDAvis
#     LDAvis_load_lib("https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js", function(){
#          LDAvis_load_lib("https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.js", function(){
#                  new LDAvis("#" + "ldavis_el1451223822337851603326287156", ldavis_el1451223822337851603326287156_data);
#             })
#          });
# }
# </script>

# %%
# define functiont to fit and plot t-SNE model

def plot_tsne(data, threshold):
    # filter data according to threshold
    index_meet_threshold = numpy.amax(data, axis=1) >= threshold
    lda_transform_filt = data[index_meet_threshold]
    
    # fit tsne model
    # x-d -> 2-d, x = number of topics
    tsne = sklearn.manifold.TSNE(
        n_components=2, 
        verbose=0, 
        random_state=0, 
        angle=0.5, 
        init='pca'
    )
    tsne_fit = tsne.fit_transform(lda_transform_filt)
    
    # most probable topic for each headline
    most_prob_topic = []
    for i in range(tsne_fit.shape[0]):
        most_prob_topic.append(lda_transform_filt[i].argmax())
    
    print("LENGTH:\n{}\n".format(len(most_prob_topic)))

    unique, counts = numpy.unique(
        numpy.array(most_prob_topic), 
        return_counts=True
    )

    print("COUNTS:\n{}\n".format(numpy.asarray((unique, counts)).T))
    
    # make plot
    color_list = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

    for i in list(set(most_prob_topic)):
        indices = [idx for idx, val in enumerate(most_prob_topic) if val == i]
        matplotlib.pyplot.scatter(
            x=tsne_fit[indices, 0], 
            y=tsne_fit[indices, 1], 
            s=0.5, 
            c=color_list[i], 
            label='Topic' + str(i),
            alpha=0.25
        )

    matplotlib.pyplot.xlabel('x-tsne')
    matplotlib.pyplot.ylabel('y-tsne')
    matplotlib.pyplot.legend(markerscale=10)

# %%
plot_tsne(data=lda_transform, threshold=0.75)
# Out:
# C:\Users\fajayi\AppData\Local\anaconda3\envs\UML\lib\site-packages\sklearn\neighbors\_base.py:650: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(joblib.__version__) < LooseVersion('0.12'))
# C:\Users\fajayi\AppData\Local\anaconda3\envs\UML\lib\site-packages\sklearn\neighbors\_base.py:650: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(joblib.__version__) < LooseVersion('0.12'))
# LENGTH:
# 58412
#
# COUNTS:
# [[    0 14973]
#  [    1 24081]
#  [    2 19358]]

# %% [markdown]
# #### Exercise 7.09: Trying 4 Topics

# %%
# rerun LDA model using number of topics equal to 4

lda4 = sklearn.decomposition.LatentDirichletAllocation(
    n_components=4,  # number of topics data suggests
    learning_method="online",
    random_state=0
)
lda4.fit(clean_vec1)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='online', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=4, n_jobs=None,
#                           perp_tol=0.1, random_state=0, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
# run function to output raw matrices in nice table format

W_df4, H_df4 = get_topics(
    mod=lda4,
    vec=clean_vec1,
    names=feature_names_vec1,
    docs=raw,
    ndocs=number_docs, 
    nwords=number_words
)

# %%
# word-topic table

print(W_df4)
# Out:
#                    Topic0                 Topic1                Topic2  \
# Word0    (0.0286, report)        (0.1001, obama)     (0.1184, economy)
# Word1     (0.0188, years)    (0.0868, president)    (0.0314, economic)
# Word2  (0.0188, economic)       (0.0499, barack)      (0.0206, growth)
# Word3  (0.0178, european)    (0.0181, palestine)       (0.0189, world)
# Word4     (0.0175, would)       (0.0156, obamas)      (0.0173, global)
# Word5     (0.0171, union)         (0.015, state)       (0.0136, china)
# Word6   (0.0158, clinton)   (0.0149, washington)  (0.0128, government)
# Word7     (0.0145, issue)  (0.0141, palestinian)     (0.0127, percent)
# Word8   (0.0133, britain)        (0.0129, house)      (0.0114, market)
# Word9   (0.0131, billion)        (0.0119, white)       (0.0112, month)
#
#                      Topic3
# Word0   (0.1226, microsoft)
# Word1     (0.0281, windows)
# Word2     (0.0274, company)
# Word3  (0.0222, microsofts)
# Word4     (0.018, announce)
# Word5       (0.0128, today)
# Word6     (0.0121, release)
# Word7      (0.0105, update)
# Word8     (0.0089, surface)
# Word9    (0.0087, business)

# %%
# document-topic table

print(H_df4)
# Out:
#                                                  Topic0  \
# Doc0  (0.931, Managing the economy is the No. 1 elec...
# Doc1  (0.9269, The Obama administration is preparing...
# Doc2  (0.9248, Ruben Zaiotti, the director of the Eu...
# Doc3  (0.9158, The International Monetary Fund downg...
# Doc4  (0.9155, Former New York Yankees player Derek ...
# Doc5  (0.9155, Obama said Thursday he was disappoint...
# Doc6  (0.9149, With so many manufacturers in the fra...
# Doc7  (0.9055, paul allen airplane Microsoft co-foun...
# Doc8  (0.905, It's plausible that QE had scant real ...
# Doc9  (0.9046, President Barack Obama on Tuesday ann...
#
#                                                  Topic1  \
# Doc0  (0.973, UNITED NATIONS """ France said Friday ...
# Doc1  (0.973, French Foreign Minister Laurent Fabius...
# Doc2  (0.9725, Ahad Ha-am (the pen name of the famou...
# Doc3  (0.9725, According to a Reuters/Ipsos poll ove...
# Doc4  (0.972, Facebook's Mark Zuckerberg has caved i...
# Doc5  (0.9719, Air pollution in China could be big b...
# Doc6  (0.9719, U.S. President Barack Obama is taking...
# Doc7  (0.9716, Two new features are aimed at making ...
# Doc8  (0.9715, U.S. President Barack Obama calls on ...
# Doc9  (0.9707, Companies in the U.S. service sector ...
#
#                                                  Topic2  \
# Doc0  (0.9756, Mobile security specialist Lookout ha...
# Doc1  (0.9749, The past week was one of those where ...
# Doc2  (0.9748, Recently the Arab nations converged i...
# Doc3  (0.9748, Last year I wrote about my Surface Pr...
# Doc4  (0.9747, Dinesh D'Souza has made two movies ab...
# Doc5  (0.9747, The U.S. economy grew at a fairly hea...
# Doc6  (0.9747, These stirring words came in Presiden...
# Doc7  (0.9747, Shares of Microsoft Corporation (NASD...
# Doc8  (0.9747, The growing air transport business is...
# Doc9  (0.9739, For any cloud to be taken seriously, ...
#
#                                                  Topic3
# Doc0  (0.9749, I imagine them bonding over the moral...
# Doc1  (0.9728, A teaching method that focuses on pro...
# Doc2  (0.9711, The importance of a first good impres...
# Doc3  (0.971, The Obama administration on Friday ask...
# Doc4  (0.9686, Obama adviser Brian Deese said Friday...
# Doc5  (0.9686, The New York Times' Farhad Manjoo rec...
# Doc6  (0.9685,  Microsoft recently announced another...
# Doc7  (0.9685, &quot;Our work with Microsoft, Amazon...
# Doc8  (0.9684, President Barack Obama with Labor Sec...
# Doc9  (0.9683,  Microsoft is getting its HoloLens Au...

# %%
# iteractive visualization

lda4_plot = pyLDAvis.sklearn.prepare(lda4, clean_vec1, vectorizer1, R=10, n_jobs=1)
pyLDAvis.display(lda4_plot)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1451223823169772248838031897"></div>
# <script type="text/javascript">
#
# var ldavis_el1451223823169772248838031897_data = {"mdsDat": {"x": [-0.15218737580746347, -0.059999688028415814, -0.15260789977287856, 0.36479496360875774], "y": [-0.24127678587644338, -0.09919771057633446, 0.3225233293570371, 0.017951167095740753], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [33.780953801125236, 28.865381221902496, 22.381274601575605, 14.972390375396676]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4", "Topic4"], "Freq": [26396.0, 21185.0, 26105.0, 22632.0, 13005.0, 9181.0, 4854.0, 4741.0, 3308.0, 3832.0, 26105.2076167272, 22631.364598767264, 13004.510117774793, 4715.762608299607, 4069.41231490076, 3882.8415953641916, 3689.535635703133, 3353.9946985807746, 3092.0103102721177, 3018.940952096463, 3924.734896420321, 26395.517023463824, 4594.092002907197, 3032.6551461125746, 2839.239918594624, 2461.7832393343338, 2154.2299989822686, 1904.3332750299924, 1506.1140333218232, 1380.1586202110811, 1246.932289755184, 4223.565856809032, 3856.1207047968014, 7006.948165629292, 2842.3267937245237, 2532.982598118842, 2494.930730168534, 21185.214195268716, 4853.903732714206, 4741.098782205684, 3831.52942302988, 1815.7111035155478, 1541.6062043145237, 1494.0466502862093, 1476.2790042495376, 1460.9759053905902, 1425.4776652868013, 3107.9828416163477, 2220.0313550958394, 2087.213264800543, 1506.5765878988811, 3307.7023225448474, 2057.9121114776635, 1972.4038156058793, 1821.301743970008, 1677.449291420297, 1454.582043633882, 1270.3923578573392, 1020.4205008634393, 980.2011824020959, 976.6289402116175, 1049.1960914697654, 1346.5469946012838, 1533.6735243515386, 1510.468695201314, 2177.2023044537436, 2026.696095599534, 2174.4685463969354], "Term": ["economy", "microsoft", "obama", "president", "barack", "economic", "windows", "company", "report", "microsofts", "obama", "president", "barack", "palestine", "obamas", "washington", "palestinian", "house", "white", "administration", "state", "economy", "growth", "china", "percent", "quarter", "expect", "federal", "financial", "strong", "india", "world", "global", "economic", "government", "market", "month", "microsoft", "windows", "company", "microsofts", "update", "surface", "software", "cloud", "technology", "build", "announce", "today", "release", "business", "report", "european", "union", "clinton", "issue", "still", "executive", "impact", "challenge", "medium", "leave", "hillary", "britain", "billion", "years", "would", "economic"], "Total": [26396.0, 21185.0, 26105.0, 22632.0, 13005.0, 9181.0, 4854.0, 4741.0, 3308.0, 3832.0, 26105.987640861218, 22632.145300025368, 13005.286661895283, 4716.550536603515, 4070.1954824131603, 3883.640457978319, 3690.3162417333783, 3354.772843285738, 3092.7878053734994, 3019.725721678472, 5345.256947313654, 26396.377695724168, 4594.862843336247, 3033.430754865518, 2840.0104862587696, 2462.5507430573716, 2155.0345825603326, 1905.1546064803977, 1506.908863966153, 1380.9511730564075, 1247.737876900611, 4245.087996546197, 3907.892950014756, 9181.923132035568, 3304.2593495615843, 2996.4265399967776, 3300.3981679697877, 21185.97874246155, 4854.663078082141, 4741.877418339101, 3832.292999500214, 1816.4767949130196, 1542.3668322402043, 1494.8104597448646, 1477.0432246325724, 1461.7466311857534, 1426.252189919468, 3736.418423475162, 2921.960436192502, 2645.4335516757633, 3269.002312926962, 3308.69073642496 ...

# %% [markdown]
# #### Exercise 7.10: TF-IDF Vectorizer

# %%
# convert to bag of words model
# use tf-idf method this time

vectorizer2 = sklearn.feature_extraction.text.TfidfVectorizer(
    analyzer="word",
    max_df=0.5, 
    min_df=20, 
    max_features=number_features,
    smooth_idf=False
)
clean_vec2 = vectorizer2.fit_transform(clean_sentences)
print(clean_vec2[0])
# Out:
#   (0, 408)	0.6671806446411689
#   (0, 88)	0.2807192050959593
#   (0, 645)	0.2348451238906006
#   (0, 558)	0.46659153068315845
#   (0, 573)	0.4507846787392432

# %%
feature_names_vec2 = vectorizer2.get_feature_names()
feature_names_vec2
# Out:
# ['abbas',
#  'ability',
#  'accelerate',
#  'accept',
#  'access',
#  'accord',
#  'account',
#  'accused',
#  'achieve',
#  'acknowledge',
#  'acquire',
#  'acquisition',
#  'across',
#  'action',
#  'activist',
#  'activity',
#  'actually',
#  'addition',
#  'address',
#  'administration',
#  'admit',
#  'advance',
#  'adviser',
#  'affairs',
#  'affect',
#  'africa',
#  'african',
#  'afternoon',
#  'agency',
#  'agenda',
#  'agree',
#  'agreement',
#  'ahead',
#  'alberta',
#  'allies',
#  'allow',
#  'almost',
#  'along',
#  'already',
#  'although',
#  'always',
#  'amazon',
#  'america',
#  'american',
#  'among',
#  'amount',
#  'analysis',
#  'analyst',
#  'android',
#  'anniversary',
#  'announce',
#  'announcement',
#  'annual',
#  'another',
#  'answer',
#  'antonin',
#  'appeal',
#  'appear',
#  'apple',
#  'application',
#  'approach',
#  'approve',
#  'april',
#  'arabia',
#  'argentina',
#  'argue',
#  'around',
#  'arrive',
#  'article',
#  'asian',
#  'assistant',
#  'associate',
#  'association',
#  'attack',
#  'attempt',
#  'attend',
#  'attention',
#  'augment',
#  'australia',
#  'australian',
#  'author',
#  'authorities',
#  'authority',
#  'available',
#  'average',
#  'award',
#  'azure',
#  'banks',
#  'barack',
#  'battle',
#  'become',
#  'begin',
#  'beginning',
#  'behind',
#  'beijing',
#  'belief',
#  'believe',
#  'benefit',
#  'bernardino',
#  'bernie',
#  'better',
#  'billion',
#  'black',
#  'blame',
#  'block',
#  'bloomberg',
#  'board',
#  'boost',
#  'border',
#  'brand',
#  'brazil',
#  'break',
#  'brexit',
#  'bring',
#  'bringing',
#  'britain',
#  'british',
#  'broad',
#  'browser',
#  'brussels',
#  'budget',
#  'build',
#  'building',
#  'bureau',
#  'business',
#  'california',
#  'calling',
#  'campaign',
#  'canada',
#  'canadian',
#  'candidate',
#  'capital',
#  'carry',
#  'cause',
#  'celebrate',
#  'center',
#  'central',
#  'centre',
#  'century',
#  'ceremony',
#  'chair',
#  'chairman',
#  'challenge',
#  'chance',
#  'change',
#  'charge',
#  'check',
#  'chicago',
#  'chief',
#  'child',
#  'china',
#  'chinese',
#  'choice',
#  'choose',
#  'chris',
#  'christmas',
#  'citizen',
#  'civil',
#  'claim',
#  'class',
#  'clear',
#  'climate',
#  'clinton',
#  'close',
#  'cloud',
#  'collapse',
#  'college',
#  'combat',
#  'coming',
#  'comment',
#  'commerce',
#  'commission',
#  'commitment',
#  'committee',
#  'commodity',
#  'community',
#  'company',
#  'compare',
#  'complete',
#  'computer',
#  'computing',
#  'concern',
#  'conditions',
#  'conference',
#  'confidence',
#  'confirm',
#  'conflict',
#  'congress',
#  'connect',
#  'conservative',
#  'consider',
#  'console',
#  'construction',
#  'consumer',
#  'consumption',
#  'content',
#  'continue',
#  'contract',
#  'contribute',
#  'control',
#  'cooperation',
#  'corporate',
#  'corporation',
#  'cortana',
#  'could',
#  'council',
#  'country',
#  'county',
#  'couple',
#  'course',
#  'court',
#  'cover',
#  'create',
#  'credit',
#  'crisis',
#  'critical',
#  'criticism',
#  'criticize',
#  'cuban',
#  'currency',
#  'current',
#  'currently',
#  'customer',
#  'daily',
#  'damage',
#  'daughter',
#  'david',
#  'death',
#  'debate',
#  'decade',
#  'december',
#  'decide',
#  'decision',
#  'declare',
#  'decline',
#  'defend',
#  'defense',
#  'delhi',
#  'deliver',
#  'demand',
#  'democrat',
#  'democratic',
#  'department',
#  'deputy',
#  'describe',
#  'design',
#  'despite',
#  'details',
#  'develop',
#  'developer',
#  'developing',
#  'development',
#  'device',
#  'devices',
#  'different',
#  'difficult',
#  'digital',
#  'dinner',
#  'direct',
#  'director',
#  'discus',
#  'discuss',
#  'discussion',
#  'display',
#  'district',
#  'document',
#  'dollar',
#  'domestic',
#  'donald',
#  'download',
#  'downturn',
#  'drive',
#  'driver',
#  'dynamics',
#  'earlier',
#  'early',
#  'earnings',
#  'economic',
#  'economist',
#  'economy',
#  'economyquot',
#  'edition',
#  'education',
#  'effect',
#  'effort',
#  'eight',
#  'elect',
#  'election',
#  'email',
#  'emerge',
#  'employee',
#  'employer',
#  'employment',
#  'enable',
#  'encourage',
#  'endorse',
#  'energy',
#  'engine',
#  'england',
#  'enough',
#  'ensure',
#  'enter',
#  'enterprise',
#  'environment',
#  'especially',
#  'estimate',
#  'europe',
#  'european',
#  'eurozone',
#  'event',
#  'every',
#  'everything',
#  'evidence',
#  'exchange',
#  'executive',
#  'exist',
#  'expand',
#  'expansion',
#  'expect',
#  'expectation',
#  'experience',
#  'expert',
#  'explain',
#  'explorer',
#  'export',
#  'express',
#  'extend',
#  'external',
#  'facebook',
#  'facing',
#  'factor',
#  'family',
#  'feature',
#  'february',
#  'federal',
#  'fight',
#  'figure',
#  'final',
#  'finally',
#  'finance',
#  'financial',
#  'first',
#  'fiscal',
#  'florida',
#  'focus',
#  'follow',
#  'following',
#  'force',
#  'forecast',
#  'foreign',
#  'former',
#  'forum',
#  'forward',
#  'found',
#  'foundation',
#  'fourth',
#  'france',
#  'francisco',
#  'freedom',
#  'french',
#  'fresh',
#  'friday',
#  'friend',
#  'front',
#  'funding',
#  'future',
#  'gaming',
#  'garland',
#  'gather',
#  'general',
#  'generate',
#  'generation',
#  'george',
#  'german',
#  'germany',
#  'getting',
#  'giant',
#  'given',
#  'giving',
#  'global',
#  'going',
#  'google',
#  'government',
#  'governor',
#  'grant',
#  'great',
#  'greater',
#  'gross',
#  'ground',
#  'group',
#  'growing',
#  'growth',
#  'hands',
#  'happen',
#  'hardware',
#  'havana',
#  'headset',
#  'health',
#  'helping',
#  'higher',
#  'highlight',
#  'hillary',
#  'hiroshima',
#  'historic',
#  'history',
#  'holding',
#  'holiday',
#  'hololens',
#  'honor',
#  'hours',
#  'house',
#  'however',
#  'human',
#  'hundred',
#  'identify',
#  'image',
#  'immigration',
#  'impact',
#  'important',
#  'improve',
#  'improvement',
#  'include',
#  'income',
#  'increase',
#  'increasingly',
#  'independent',
#  'index',
#  'india',
#  'indian',
#  'indicate',
#  'indicator',
#  'indonesia',
#  'industrial',
#  'industry',
#  'inflation',
#  'information',
#  'infrastructure',
#  'initiative',
#  'innovation',
#  'inside',
#  'insider',
#  'instead',
#  'institute',
#  'intelligence',
#  'interest',
#  'international',
#  'internet',
#  'interview',
#  'introduce',
#  'investment',
#  'investor',
#  'involve',
#  'ireland',
#  'islamic',
#  'island',
#  'israel',
#  'israeli',
#  'issue',
#  'january',
#  'japan',
#  'japanese',
#  'jerusalem',
#  'jewish',
#  'joint',
#  'journalist',
#  'judge',
#  'justice',
#  'justin',
#  'keeping',
#  'keyboard',
#  'kingdom',
#  'korea',
#  'kuala',
#  'labor',
#  'labour',
#  'laptop',
#  'large',
#  'largely',
#  'later',
#  'latest',
#  'launch',
#  'lawmaker',
#  'leader',
#  'leaders',
#  'leadership',
#  'leading',
#  'learn',
#  'least',
#  'leave',
#  'leaving',
#  'legacy',
#  'legal',
#  'legislation',
#  'letter',
#  'level',
#  'liberation',
#  'likely',
#  'linkedin',
#  'linux',
#  'little',
#  'local',
#  'london',
#  'longer',
#  'looking',
#  'lower',
#  'lumia',
#  'lumpur',
#  'machine',
#  'mahmoud',
#  'maintain',
#  'major',
#  'majority',
#  'maker',
#  'making',
#  'malaysia',
#  'manage',
#  'management',
#  'manager',
#  'manufacturing',
#  'march',
#  'market',
#  'massive',
#  'matter',
#  'mayor',
#  'means',
#  'measure',
#  'medium',
#  'meeting',
#  'member',
#  'mention',
#  'message',
#  'michelle',
#  'michigan',
#  'microsoft',
#  'microsofts',
#  'middle',
#  'middot',
#  'might',
#  'military',
#  'million',
#  'minister',
#  'ministry',
#  'mobile',
#  'model',
#  'moment',
#  'momentum',
#  'monday',
#  'monetary',
#  'money',
#  'month',
#  'morning',
#  'moscow',
#  'mosque',
#  'movement',
#  'muslim',
#  'nadella',
#  'nasdaqmsft',
#  'nation',
#  'national',
#  'nearly',
#  'negative',
#  'network',
#  'never',
#  'nigeria',
#  'night',
#  'nominate',
#  'nomination',
#  'nominee',
#  'north',
#  'november',
#  'nuclear',
#  'number',
#  'numbers',
#  'obama',
#  'obamas',
#  'occupation',
#  'occupy',
#  'october',
#  'offer',
#  'offering',
#  'office',
#  'officer',
#  'official',
#  'officially',
#  'often',
#  'ongoing',
#  'online',
#  'opening',
#  'operate',
#  'opportunity',
#  'opposition',
#  'optimistic',
#  'option',
#  'order',
#  'organization',
#  'orlando',
#  'others',
#  'outlook',
#  'output',
#  'outside',
#  'overall',
#  'owner',
#  'palestine',
#  'palestinian',
#  'paris',
#  'parliament',
#  'particularly',
#  'partner',
#  'partnership',
#  'party',
#  'patch',
#  'peace',
#  'people',
#  'percent',
#  'performance',
#  'period',
#  'person',
#  'personal',
#  'phone',
#  'photo',
#  'picture',
#  'place',
#  'planning',
#  'platform',
#  'player',
#  'pledge',
#  'plunge',
#  'point',
#  'police',
#  'policy',
#  'political',
#  'politics',
#  'popular',
#  'position',
#  'positive',
#  'possible',
#  'potential',
#  'power',
#  'powerful',
#  'praise',
#  'predict',
#  'premier',
#  'prepare',
#  'present',
#  'presidency',
#  'president',
#  'presidential',
#  'press',
#  'pressure',
#  'presumptive',
#  'pretty',
#  'prevent',
#  'preview',
#  'previous',
#  'previously',
#  'price',
#  'primary',
#  'prime',
#  'priority',
#  'prison',
#  'private',
#  'probably',
#  'problem',
#  'process',
#  'produce',
#  'product',
#  'production',
#  'productivity',
#  'professional',
#  'program',
#  'progress',
#  'project',
#  'promise',
#  'promote',
#  'proposal',
#  'propose',
#  'prospect',
#  'protect',
#  'protection',
#  'provide',
#  'provider',
#  'public',
#  'publish',
#  'purchase',
#  'pushing',
#  'putin',
#  'quarter',
#  'quarterly',
#  'question',
#  'quickly',
#  'quite',
#  'quota',
#  'quoti',
#  'quotthe',
#  'quotwe',
#  'raise',
#  'raising',
#  'rally',
#  'ramallah',
#  'range',
#  'rates',
#  'rather',
#  'rating',
#  'reach',
#  'ready',
#  'reality',
#  'really',
#  'reason',
#  'rebound',
#  'receive',
#  'recent',
#  'recently',
#  'recession',
#  'recognize',
#  'record',
#  'recover',
#  'recovery',
#  'redmond',
#  'reduce',
#  'referendum',
#  'reflect',
#  'reform',
#  'refugee',
#  'refuse',
#  'regard',
#  'region',
#  'regional',
#  'regulation',
#  'relate',
#  'relations',
#  'relationship',
#  'release',
#  'remain',
#  'remains',
#  'remark',
#  'replace',
#  'report',
#  'reporter',
#  'represent',
#  'republican',
#  'request',
#  'require',
#  'research',
#  'researcher',
#  'reserve',
#  'resident',
#  'resolution',
#  'resource',
#  'respond',
#  'response',
#  'result',
#  'retail',
#  'return',
#  'reuters',
#  'reveal',
#  'revenue',
#  'review',
#  'revive',
#  'right',
#  'rising',
#  'rival',
#  'robust',
#  'round',
#  'running',
#  'russia',
#  'russian',
#  'sales',
#  'sanction',
#  'sander',
#  'saturday',
#  'satya',
#  'saudi',
#  'saying',
#  'scalia',
#  'schedule',
#  'school',
#  'science',
#  'search',
#  'season',
#  'second',
#  'secretary',
#  'sector',
#  'secure',
#  'security',
#  'seeking',
#  'select',
#  'senate',
#  'senator',
#  'senior',
#  'sense',
#  'sentence',
#  'september',
#  'series',
#  'serious',
#  'serve',
#  'server',
#  'service',
#  'services',
#  'session',
#  'seven',
#  'several',
#  'share',
#  'sharing',
#  'sharp',
#  'shift',
#  'shock',
#  'shooting',
#  'short',
#  'showing',
#  'shrink',
#  'signal',
#  'significant',
#  'similar',
#  'since',
#  'singapore',
#  'single',
#  'sitting',
#  'situation',
#  'skype',
#  'slightly',
#  'slowdown',
#  'slowing',
#  'sluggish',
#  'slump',
#  'small',
#  'smart',
#  'smartphone',
#  'socalled',
#  'social',
#  'society',
#  'software',
#  'solid',
#  'solidarity',
#  'solution',
#  'something',
#  'sound',
#  'source',
#  'south',
#  'southeast',
#  'space',
#  'speak',
#  'speaker',
#  'speaking',
#  'special',
#  'speech',
#  'spend',
#  'spending',
#  'spoke',
#  'spring',
#  'staff',
#  'stage',
#  'stand',
#  'standard',
#  'start',
#  'starting',
#  'startup',
#  'state',
#  'statement',
#  'statistics',
#  'steady',
#  'steps',
#  'still',
#  'stimulus',
#  'stock',
#  'stocks',
#  'storage',
#  'store',
#  'story',
#  'strategy',
#  'street',
#  'strength',
#  'strike',
#  'strong',
#  'struggle',
#  'student',
#  'studio',
#  'study',
#  'success',
#  'suffer',
#  'suggest',
#  'summer',
#  'summit',
#  'sunday',
#  'support',
#  'supporter',
#  'supreme',
#  'surface',
#  'surge',
#  'surprise',
#  'survey',
#  'syria',
#  'syrian',
#  'system',
#  'tablet',
#  'tackle',
#  'taking',
#  'talks',
#  'target',
#  'technology',
#  'terms',
#  'territory',
#  'terror',
#  'terrorism',
#  'terrorist',
#  'texas',
#  'thanks',
#  'thats',
#  'there',
#  'thing',
#  'things',
#  'think',
#  'third',
#  'though',
#  'thought',
#  'thousand',
#  'threat',
#  'threaten',
#  'three',
#  'throw',
#  'thursday',
#  'times',
#  'title',
#  'today',
#  'together',
#  'tokyo',
#  'total',
#  'tough',
#  'tourism',
#  'toward',
#  'towards',
#  'track',
#  'trade',
#  'trading',
#  'transgender',
#  'transition',
#  'travel',
#  'trend',
#  'trillion',
#  'trouble',
#  'trudeau',
#  'trump',
#  'tuesday',
#  'turkey',
#  'twitter',
#  'uncertainty',
#  'unemployment',
#  'union',
#  'unite',
#  'university',
#  'unveil',
#  'upcoming',
#  'update',
#  'upgrade',
#  'using',
#  'value',
#  'vehicle',
#  'version',
#  'victim',
#  'video',
#  'vietnam',
#  'violence',
#  'virtual',
#  'vision',
#  'visit',
#  'vladimir',
#  'voice',
#  'voter',
#  'warning',
#  'washington',
#  'watch',
#  'water',
#  'weakness',
#  'website',
#  'wednesday',
#  'weekend',
#  'weigh',
#  'welcome',
#  'western',
#  'whats',
#  'whether',
#  'white',
#  'whose',
#  'windows',
#  'within',
#  'without',
#  'woman',
#  'words',
#  'worker',
#  'working',
#  'works',
#  'world',
#  'worry',
#  'worst',
#  'worth',
#  'would',
#  'write',
#  'years',
#  'yellen',
#  'yesterday',
#  'young']

# %% [markdown]
# #### Exercise 7.11: Non-negative Matrix Factorization

# %%
# define and fit nmf model

nmf = sklearn.decomposition.NMF(
    n_components=4,
    init="nndsvda",
    solver="mu",
    beta_loss="frobenius",
    random_state=0, 
    alpha=0.1, 
    l1_ratio=0.5
)
nmf.fit(clean_vec2)
# Out:
# NMF(alpha=0.1, beta_loss='frobenius', init='nndsvda', l1_ratio=0.5,
#     max_iter=200, n_components=4, random_state=0, shuffle=False, solver='mu',
#     tol=0.0001, verbose=0)

# %%
# run function to produce nice output tables

W_df, H_df = get_topics(
    mod=nmf,
    vec=clean_vec2,
    names=feature_names_vec2,
    docs=raw,
    ndocs=number_docs, 
    nwords=number_words
)

# %%
# word-topic table

print(W_df)
# Out:
#                          Topic0              Topic1                Topic2  \
# Word0           (0.0697, obama)   (0.0628, economy)   (0.0871, microsoft)
# Word1       (0.0646, president)  (0.0212, economic)     (0.0305, windows)
# Word2          (0.0484, barack)    (0.0179, growth)     (0.0196, company)
# Word3      (0.0157, washington)    (0.0144, global)    (0.0162, announce)
# Word4           (0.0149, house)     (0.0128, china)  (0.0124, microsofts)
# Word5           (0.0144, white)   (0.0111, percent)      (0.0117, update)
# Word6          (0.0127, obamas)     (0.0109, world)     (0.0105, release)
# Word7           (0.0108, state)   (0.0096, quarter)         (0.01, today)
# Word8  (0.0096, administration)    (0.0093, market)     (0.0096, surface)
# Word9           (0.0081, first)   (0.0086, country)       (0.0085, cloud)
#
#                         Topic3
# Word0      (0.0879, palestine)
# Word1    (0.0765, palestinian)
# Word2         (0.031, israeli)
# Word3         (0.0279, israel)
# Word4          (0.0172, state)
# Word5  (0.0094, international)
# Word6       (0.0092, ramallah)
# Word7        (0.009, minister)
# Word8           (0.008, unite)
# Word9          (0.0078, force)

# %%
# document-topic table

print(H_df)
# Out:
#                                                  Topic0  \
# Doc0  (0.0844, Facebook, Twitter, Google's YouTube a...
# Doc1  (0.0844, Microsoft is sending out invites for ...
# Doc2  (0.0844, J.W. Mason, a John Jay College assist...
# Doc3  (0.0844, &quot;It's a false economy that savin...
# Doc4  (0.0844, (CNN) """Leaders gathered in Paris to...
# Doc5  (0.0844, President Barack Obama would be tied ...
# Doc6  (0.0844, President Obama met with gun control ...
# Doc7  (0.0844, As part of President Obama's ongoing ...
# Doc8  (0.0844, New Microsoft Surface Pro 4s sit on d...
# Doc9  (0.0844, Globally, there is a shortfall of eco...
#
#                                                  Topic1  \
# Doc0  (0.0677, The world's small and medium business...
# Doc1  (0.0677, The Raspberry Pi 2s Model B is being ...
# Doc2  (0.0677, BELEK, Turkey, Nov 16 (Reuters) - The...
# Doc3  (0.0677, Under Steve Ballmer, Microsoft (NASDA...
# Doc4  (0.0677, In the current economy or the offline...
# Doc5  (0.0677, The maximum length for a path (file n...
# Doc6  (0.0677, PARIS"""IoT network infrastructure pr...
# Doc7  (0.0677, He indicated he wanted to kill Obama'...
# Doc8  (0.0677, At the same time, it raises two quest...
# Doc9  (0.0677, """San Angelo continued to experience...
#
#                                                  Topic2  \
# Doc0  (0.0837, Leaving the EU would stunt the Britis...
# Doc1  (0.0837, Doug Parker and Keith Wilson fail to ...
# Doc2  (0.0837, Together, this begs the big question ...
# Doc3  (0.0837,  to a person. In February, the House ...
# Doc4  (0.0837, If there is one area on which the mor...
# Doc5  (0.0837, Previously in this series, we discuss...
# Doc6  (0.0837, Microsoft failed to tell users of its...
# Doc7  (0.0837, Chandauli: The ban on liquor consumpt...
# Doc8  (0.0837, The Chinese President Xi Jinping told...
# Doc9  (0.0837, President Obama says every student in...
#
#                                                  Topic3
# Doc0  (0.1077, KUALA LUMPUR: Malaysia's economy is p...
# Doc1  (0.1077, WASHINGTON """ President Obama's deci...
# Doc2  (0.0856, Microsoft has made its first update f...
# Doc3  (0.0852, """This is excellent news and a signi...
# Doc4  (0.0841, The economy is still creating jobs"""...
# Doc5  (0.0827, I hope the Committee on the Future Ec...
# Doc6  (0.0814, Microsoft's Project Scorpio reportedl...
# Doc7  (0.0814, Microsoft today announced the availab...
# Doc8  (0.0814, The McGraw-Hill Education book publis...
# Doc9  (0.0814, JOHANNESBURG (AP) — South Africa's st...

# %% [markdown]
# #### Exercise 7.12: Visualizing NMF

# %%
# output raw document-topic matrix for t-SNE plot

nmf_transform = nmf.transform(clean_vec2)
print(nmf_transform.shape)
print(nmf_transform)
# Out:
# (92950, 4)
# [[5.12572377e-02 3.78141387e-15 3.21728241e-34 7.75200820e-16]
#  [7.34488427e-04 2.04030192e-02 6.79068276e-15 2.16111635e-03]
#  [3.01270059e-15 1.94011838e-02 4.16472878e-21 1.20147175e-18]
#  ...
#  [9.57618659e-06 3.40954191e-03 6.16312005e-04 3.23857611e-02]
#  [6.54632838e-07 1.34685958e-07 3.41038290e-08 6.13707926e-02]
#  [4.63885940e-05 1.18933175e-04 1.84290226e-02 2.01258153e-03]]

# %%
# run function to produce t-SNE plot

plot_tsne(data=nmf_transform, threshold=0)
# Out:
# C:\Users\fajayi\AppData\Local\anaconda3\envs\UML\lib\site-packages\sklearn\neighbors\_base.py:650: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(joblib.__version__) < LooseVersion('0.12'))
# C:\Users\fajayi\AppData\Local\anaconda3\envs\UML\lib\site-packages\sklearn\neighbors\_base.py:650: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   LooseVersion(joblib.__version__) < LooseVersion('0.12'))
# LENGTH:
# 92950
#
# COUNTS:
# [[    0 28966]
#  [    1 32951]
#  [    2 22145]
#  [    3  8888]]
